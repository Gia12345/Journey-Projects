# %% [markdown]
# #  Walt Disney World On Site Hotel Addresses

# %% [markdown]
# ## Using touringplans.com website, scrape 3 web pages, combine and put information into a dataframe, and save to csv file.
#
# ### The first web page contains resort hotel addresses, the second web page, which will be used as the master list of resort hotels, contains the resort area information, and the third web page contains the number of rooms for each resort hotel.  After scraping, information for each web page is put into a dataframe.
#
# ### The 3 dataframes will be combined into one dataframe and saved to a csv file.

# %% [markdown]
# Import libraries.

# %%
import numpy as np
import pandas as pd
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
from unidecode import unidecode
from fuzzywuzzy import fuzz, process

# %% [markdown]
# Define function to get table from soup object.

# %%
def get_table_from_soup(soup, columns, drop_rows):
    l = []
    table_rows=soup.find_all('tr')
    for tr in table_rows:
        td = tr.find_all('td')
        row = [unidecode(d.text.strip()) for d in td]
        l.append(row)
    df=pd.DataFrame(l)
    df=df.drop([2, 3], axis=1)
    df=df.drop(drop_rows, axis=0)
    df.columns=columns
    return df

# %% [markdown]
# ### 1.  Get addresses from touringplans.com page.

# %%
url='https://touringplans.com/walt-disney-world/hotels/addresses'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# Use BeautifulSoup to parse web page.

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# Get rows from web page.

# %%
columns=['Resort', 'Address']
drop_rows=[41, 42]
df=get_table_from_soup(soup, columns, drop_rows)
df['Address']=df['Address'].map(lambda a: a.replace('\t', '').replace('\n', ' '))
df
# Out:
#                                                Resort  \
# 0         B Resort & Spa - Disney Springs Resort Area
# 1      Bay Lake Tower at Disney's Contemporary Resort
# 2   Best Western Lake Buena Vista - Disney Springs...
# 3   Boulder Ridge Villas at Disney's Wilderness Lodge
# 4   Copper Creek Villas & Cabins at Disney's Wilde...
# 5                     Disney's All-Star Movies Resort
# 6                      Disney's All-Star Music Resort
# 7                     Disney's All-Star Sports Resort
# 8         Disney's Animal Kingdom Lodge - Jambo House
# 9     Disney's Animal Kingdom Villas - Kidani Village
# 10                   Disney's Art of Animation Resort
# 11                         Disney's Beach Club Resort
# 12                         Disney's Beach Club Villas
# 13                             Disney's BoardWalk Inn
# 14                          Disney's BoardWalk Villas
# 15                    Disney's Caribbean Beach Resort
# 16                       Disney's Contemporary Resort
# 17                   Disney's Coronado Springs Resort
# 18              Disney's Grand Floridian Resort & Spa
# 19                       Disney's Old Key West Resort
# 20                 Disney's Polynesian Village Resort
# 21             Disney's Polynesian Villas & Bungalows
# 22                        Disney's Pop Century Resort
# 23      Disney's Port Orleans Resort - French Quarter
# 24           Disney's Port Orleans Resort - Riverside
# 25                            Disney's Riviera Resort
# 26             Disney's Saratoga Springs Resort & Spa
# 27                          Disney's Wilderness Lodge
# 28                         Disney's Yacht Club Resort
# 29                       Dolphin at Walt Disney World
# 30  DoubleTree Suites by Hilton Orlando - Disney S...
# 31  Four Seasons Resort Orlando at Walt Disney Wor...
# 32  Hilton Orlando Buena Vista Palace - Disney Spr...
# 33  Hilton Orlando Lake Buena Vista - Disney Sprin...
# 34          Holiday Inn Orlando - Disney Springs Area
# 35               Shades of Green at Walt Disney World
# 36                          Swan at Walt Disney World
# 37      The Cabins at Disney's Fort Wilderness Resort
# 38  The Villas at Disney's Grand Floridian Resort ...
print(soup.find('h2',text='Magic Kingdom Area Resorts').find_next('li'))
# Out:
# <li><a href="/walt-disney-world/hotels/copper-creek-villas">Copper Creek Villas &amp; Cabins at Disney's Wilderness Lodge</a> (Deluxe Villa)</li>

# %%
"""
start = soup.find('h2',text='Magic Kingdom Area Resorts')
start.next_element
for element in start.next_elements:
    print(repr(element))
"""
# Out:
# "\nstart = soup.find('h2',text='Magic Kingdom Area Resorts')\nstart.next_element\nfor element in start.next_elements:\n    print(repr(element))\n"

# %%
def get_resort_by_area(soup_area, number_of_resorts, area):
    start = soup.find('h2',text=soup_area)
    resorts=[]
    for i in range(number_of_resorts):
        resort_name=start.find_next('li').text
        resorts.append(resort_name)
        start=start.find_next('li')
    df=pd.DataFrame(resorts, columns=['Resort'])
    df['Resort Area']=area
    return df

# %%
df_mk_resorts=get_resort_by_area('Magic Kingdom Area Resorts', 9, 'Magic Kingdom')
df_mk_resorts
# Out:
#                                               Resort    Resort Area
# 0  Copper Creek Villas & Cabins at Disney's Wilde...  Magic Kingdom
# 1       Disney’s Contemporary Resort (Deluxe Resort)  Magic Kingdom
# 2    Disney’s Grand Floridian Resort (Deluxe Resort)  Magic Kingdom
# 3         Disney’s Polynesian Resort (Deluxe Resort)  Magic Kingdom
# 4          Disney’s Wilderness Lodge (Deluxe Resort)  Magic Kingdom
# 5  Bay Lake Tower at Disney’s Contemporary Resort...  Magic Kingdom
# 6  The Villas at Disney’s Grand Floridian Resort ...  Magic Kingdom
# 7    Disney’s Wilderness Lodge Villas (Deluxe Villa)  Magic Kingdom
# 8  Disney’s Fort Wilderness Resort Cabins (Modera...  Magic Kingdom

# %%
df_e_resorts=get_resort_by_area('Epcot Area Resorts', 11, 'Epcot')
df_e_resorts
# Out:
#                                                Resort Resort Area
# 0          Disney’s Beach Club Resort (Deluxe Resort)       Epcot
# 1              Disney’s BoardWalk Inn (Deluxe Resort)       Epcot
# 2          Disney’s Yacht Club Resort (Deluxe Resort)       Epcot
# 3   Dolphin at Walt Disney World (Not operated by ...       Epcot
# 4    Swan at Walt Disney World (Not operated by Di...       Epcot
# 5           Disney’s Beach Club Villas (Deluxe Villa)       Epcot
# 6            Disney’s BoardWalk Villas (Deluxe Villa)       Epcot
# 7              Disney's Riviera Resort (Deluxe Villa)       Epcot
# 8   Disney’s Caribbean Beach Resort (Moderate Resort)       Epcot
# 9     Disney’s Art of Animation Resort (Value Resort)       Epcot
# 10         Disney’s Pop Century Resort (Value Resort)       Epcot

# %%
df_ak_resorts=get_resort_by_area('Animal Kingdom Area Resorts', 6, 'Animal Kingdom')
df_ak_resorts
# Out:
#                                               Resort     Resort Area
# 0      Disney’s Animal Kingdom Lodge (Deluxe Resort)  Animal Kingdom
# 1      Disney’s Animal Kingdom Villas (Deluxe Villa)  Animal Kingdom
# 2  Disney’s Coronado Springs Resort (Moderate Res...  Animal Kingdom
# 3     Disney’s All-Star Movies Resort (Value Resort)  Animal Kingdom
# 4      Disney’s All-Star Music Resort (Value Resort)  Animal Kingdom
# 5    Disney’s All-Star Sports Resort  (Value Resort)  Animal Kingdom

# %%
df_ds_resorts=get_resort_by_area('Bonnet Creek Area Resorts', 4, 'Disney Springs')
df_ds_resorts
# Out:
#                                               Resort     Resort Area
# 0        Disney’s Old Key West Resort (Deluxe Villa)  Disney Springs
# 1  Disney’s Saratoga Springs Resort & Spa (Deluxe...  Disney Springs
# 2  Disney’s Port Orleans Resort – French Quarter ...  Disney Springs
# 3  Disney’s Port Orleans Resort – Riverside (Mode...  Disney Springs

# %%
df_resort_areas=df_mk_resorts.append([df_e_resorts, df_ak_resorts, df_ds_resorts])
df_resort_areas.reset_index(drop=True, inplace=True)
df_resort_areas
# Out:
#                                                Resort     Resort Area
# 0   Copper Creek Villas & Cabins at Disney's Wilde...   Magic Kingdom
# 1        Disney’s Contemporary Resort (Deluxe Resort)   Magic Kingdom
# 2     Disney’s Grand Floridian Resort (Deluxe Resort)   Magic Kingdom
# 3          Disney’s Polynesian Resort (Deluxe Resort)   Magic Kingdom
# 4           Disney’s Wilderness Lodge (Deluxe Resort)   Magic Kingdom
# 5   Bay Lake Tower at Disney’s Contemporary Resort...   Magic Kingdom
# 6   The Villas at Disney’s Grand Floridian Resort ...   Magic Kingdom
# 7     Disney’s Wilderness Lodge Villas (Deluxe Villa)   Magic Kingdom
# 8   Disney’s Fort Wilderness Resort Cabins (Modera...   Magic Kingdom
# 9          Disney’s Beach Club Resort (Deluxe Resort)           Epcot
# 10             Disney’s BoardWalk Inn (Deluxe Resort)           Epcot
# 11         Disney’s Yacht Club Resort (Deluxe Resort)           Epcot
# 12  Dolphin at Walt Disney World (Not operated by ...           Epcot
# 13   Swan at Walt Disney World (Not operated by Di...           Epcot
# 14          Disney’s Beach Club Villas (Deluxe Villa)           Epcot
# 15           Disney’s BoardWalk Villas (Deluxe Villa)           Epcot
# 16             Disney's Riviera Resort (Deluxe Villa)           Epcot
# 17  Disney’s Caribbean Beach Resort (Moderate Resort)           Epcot
# 18    Disney’s Art of Animation Resort (Value Resort)           Epcot
# 19         Disney’s Pop Century Resort (Value Resort)           Epcot
# 20      Disney’s Animal Kingdom Lodge (Deluxe Resort)  Animal Kingdom
# 21      Disney’s Animal Kingdom Villas (Deluxe Villa)  Animal Kingdom
# 22  Disney’s Coronado Springs Resort (Moderate Res...  Animal Kingdom
# 23     Disney’s All-Star Movies Resort (Value Resort)  Animal Kingdom
# 24      Disney’s All-Star Music Resort (Value Resort)  Animal Kingdom
# 25    Disney’s All-Star Sports Resort  (Value Resort)  Animal Kingdom
# 26        Disney’s Old Key West Resort (Deluxe Villa)  Disney Springs
# 27  Disney’s Saratoga Springs Resort & Spa (Deluxe...  Disney Springs
# 28  Disney’s Port Orleans Resort – French Quarter ...  Disney Springs
# 29  Disney’s Port Orleans Resort – Riverside (Mode...  Disney Springs

# %%
'Disney’s Contemporary Resort (Deluxe Resort)'.split('(')[0]
# Out:
# 'Disney’s Contemporary Resort '

# %%
df_resort_areas['Resort']=df_resort_areas['Resort'].apply(lambda x: x.split('(')[0])
df_resort_areas
# Out:
#                                                Resort     Resort Area
# 0   Copper Creek Villas & Cabins at Disney's Wilde...   Magic Kingdom
# 1                       Disney’s Contemporary Resort    Magic Kingdom
# 2                    Disney’s Grand Floridian Resort    Magic Kingdom
# 3                         Disney’s Polynesian Resort    Magic Kingdom
# 4                          Disney’s Wilderness Lodge    Magic Kingdom
# 5     Bay Lake Tower at Disney’s Contemporary Resort    Magic Kingdom
# 6   The Villas at Disney’s Grand Floridian Resort ...   Magic Kingdom
# 7                   Disney’s Wilderness Lodge Villas    Magic Kingdom
# 8             Disney’s Fort Wilderness Resort Cabins    Magic Kingdom
# 9                         Disney’s Beach Club Resort            Epcot
# 10                            Disney’s BoardWalk Inn            Epcot
# 11                        Disney’s Yacht Club Resort            Epcot
# 12                      Dolphin at Walt Disney World            Epcot
# 13                         Swan at Walt Disney World            Epcot
# 14                        Disney’s Beach Club Villas            Epcot
# 15                         Disney’s BoardWalk Villas            Epcot
# 16                           Disney's Riviera Resort            Epcot
# 17                   Disney’s Caribbean Beach Resort            Epcot
# 18                  Disney’s Art of Animation Resort            Epcot
# 19                       Disney’s Pop Century Resort            Epcot
# 20                     Disney’s Animal Kingdom Lodge   Animal Kingdom
# 21                    Disney’s Animal Kingdom Villas   Animal Kingdom
# 22                  Disney’s Coronado Springs Resort   Animal Kingdom
# 23                   Disney’s All-Star Movies Resort   Animal Kingdom
# 24                    Disney’s All-Star Music Resort   Animal Kingdom
# 25                  Disney’s All-Star Sports Resort    Animal Kingdom
# 26                      Disney’s Old Key West Resort   Disney Springs
# 27            Disney’s Saratoga Springs Resort & Spa   Disney Springs
# 28     Disney’s Port Orleans Resort – French Quarter   Disney Springs
# 29          Disney’s Port Orleans Resort – Riverside   Disney Springs

# %% [markdown]
# #### After using FuzzyWuzzy to match resort hotel names in section 4 below, I discovered that these particular names needed to be fixed.  I used the resort hotel names from the address page (part 1) because the names were better and more descriptive and matched the names on the number of rooms page (part 3).

# %%
def fix_resort_names(name):
    fix_name=name
    if fuzz.token_sort_ratio("Disney's Wilderness Lodge Villas", name)==100:
        fix_name="Boulder Ridge Villas at Disney's Wilderness Lodge"
    if fuzz.token_sort_ratio("Disney's Polynesian Resort", name)==100:
        fix_name="Disney's Polynesian Village Resort"
    if 'Animal Kingdom Lodge' in name:
        fix_name=name+' - Jambo House'
    if 'Animal Kingdom Villas' in name:
        fix_name=name+' - Kidani Village'
    return fix_name
df_resort_areas['Resort']=df_resort_areas['Resort'].map(lambda name: fix_resort_names(name))
df_resort_areas
# Out:
#                                                Resort     Resort Area
# 0   Copper Creek Villas & Cabins at Disney's Wilde...   Magic Kingdom
# 1                       Disney’s Contemporary Resort    Magic Kingdom
# 2                    Disney’s Grand Floridian Resort    Magic Kingdom
# 3                  Disney's Polynesian Village Resort   Magic Kingdom
# 4                          Disney’s Wilderness Lodge    Magic Kingdom
# 5     Bay Lake Tower at Disney’s Contemporary Resort    Magic Kingdom
# 6   The Villas at Disney’s Grand Floridian Resort ...   Magic Kingdom
# 7   Boulder Ridge Villas at Disney's Wilderness Lodge   Magic Kingdom
# 8             Disney’s Fort Wilderness Resort Cabins    Magic Kingdom
# 9                         Disney’s Beach Club Resort            Epcot
# 10                            Disney’s BoardWalk Inn            Epcot
# 11                        Disney’s Yacht Club Resort            Epcot
# 12                      Dolphin at Walt Disney World            Epcot
# 13                         Swan at Walt Disney World            Epcot
# 14                        Disney’s Beach Club Villas            Epcot
# 15                         Disney’s BoardWalk Villas            Epcot
# 16                           Disney's Riviera Resort            Epcot
# 17                   Disney’s Caribbean Beach Resort            Epcot
# 18                  Disney’s Art of Animation Resort            Epcot
# 19                       Disney’s Pop Century Resort            Epcot
# 20       Disney’s Animal Kingdom Lodge  - Jambo House  Animal Kingdom
# 21   Disney’s Animal Kingdom Villas  - Kidani Village  Animal Kingdom
# 22                  Disney’s Coronado Springs Resort   Animal Kingdom
# 23                   Disney’s All-Star Movies Resort   Animal Kingdom
# 24                    Disney’s All-Star Music Resort   Animal Kingdom
# 25                  Disney’s All-Star Sports Resort    Animal Kingdom
# 26                      Disney’s Old Key West Resort   Disney Springs
# 27            Disney’s Saratoga Springs Resort & Spa   Disney Springs
# 28     Disney’s Port Orleans Resort – French Quarter   Disney Springs
# 29          Disney’s Port Orleans Resort – Riverside   Disney Springs

# %%
df['Resort'][27]
# Out:
# "Disney's Wilderness Lodge"

# %%
df_resort_areas['Resort'][4]
# Out:
# 'Disney’s Wilderness Lodge '

# %%
fuzz.token_sort_ratio(df['Resort'][27], df_resort_areas['Resort'][7])
# Out:
# 68

# %%
fuzz.token_sort_ratio(df_resort_areas['Resort'][23], df_resort_areas['Resort'][24])
# Out:
# 89

# %%
print(df_resort_areas['Resort'][23], ' ', df_resort_areas['Resort'][24])
# Out:
# Disney’s All-Star Movies Resort    Disney’s All-Star Music Resort

# %%
print(df['Resort'][20], ' ', df_resort_areas['Resort'][3])
fuzz.token_sort_ratio(df['Resort'][20], df_resort_areas['Resort'][3])
# Out:
# Disney's Polynesian Village Resort   Disney's Polynesian Village Resort
# 100

# %% [markdown]
# ### 3.  Get number of rooms for each resort hotel.

# %%
url='https://touringplans.com/walt-disney-world/hotels/number-rooms'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')
rows=soup.find_all('td')

# %%
columns=['Resort', 'Number of Rooms']
drop_rows=[42, 43]
df_rooms=get_table_from_soup(soup, columns, drop_rows)
df_rooms
# Out:
#                                                Resort Number of Rooms
# 0         B Resort & Spa - Disney Springs Resort Area             394
# 1      Bay Lake Tower at Disney's Contemporary Resort             295
# 2   Best Western Lake Buena Vista - Disney Springs...             325
# 3   Boulder Ridge Villas at Disney's Wilderness Lodge             136
# 4   Copper Creek Villas & Cabins at Disney's Wilde...             220
# 5                     Disney's All-Star Movies Resort           1,920
# 6                      Disney's All-Star Music Resort           1,604
# 7                     Disney's All-Star Sports Resort           1,920
# 8         Disney's Animal Kingdom Lodge - Jambo House             972
# 9     Disney's Animal Kingdom Villas - Kidani Village             458
# 10                   Disney's Art of Animation Resort           1,984
# 11                         Disney's Beach Club Resort             583
# 12                         Disney's Beach Club Villas             282
# 13                             Disney's BoardWalk Inn             378
# 14                          Disney's BoardWalk Villas             532
# 15                    Disney's Caribbean Beach Resort           1,536
# 16                       Disney's Contemporary Resort             655
# 17                   Disney's Coronado Springs Resort           2,384
# 18              Disney's Grand Floridian Resort & Spa             867
# 19                       Disney's Old Key West Resort             761
# 20                 Disney's Polynesian Village Resort             847
# 21             Disney's Polynesian Villas & Bungalows             380
# 22                        Disney's Pop Century Resort           2,880
# 23      Disney's Port Orleans Resort - French Quarter           1,008
# 24           Disney's Port Orleans Resort - Riverside           2,048
# 25                            Disney's Riviera Resort             489
# 26             Disney's Saratoga Springs Resort & Spa           1,260
# 27                          Disney's Wilderness Lodge             430
# 28                         Disney's Yacht Club Resort             630
# 29                       Dolphin at Walt Disney World           1,509
# 30  DoubleTree Suites by Hilton Orlando - Disney S...             229
# 31  Four Seasons Resort Orlando at Walt Disney Wor...             443
# 32  Hilton Orlando Buena Vista Palace - Disney Spr...             987
# 33  Hilton Orlando Lake Buena Vista - Disney Sprin...             814
# 34          Holiday Inn Orlando - Disney Springs Area             323
# 35              Reflections - A Disney Lakeside Lodge             900
# 36               Shades of Green at Walt Disney World             586
# 37                          Swan at Walt Disney World             758
# 38      The Cabins at Disney's Fort Wilderness Resort             409
# 39  The Villas at Disney's Grand Floridian Resort ...             147
# 40  Treehouse Villas at Disney's Saratoga Springs ...              60
# 41  Wyndham Garden Lake Buena Vista Disney Springs...             626

# %% [markdown]
# ### 4.  Use FuzzyWuzzy to match resort names in each dataframe

# %%
print(df_resort_areas['Resort'][10])
len(df_resort_areas)-1
# Out:
# Disney’s BoardWalk Inn
# 29

# %%
df_resort_areas['Resort'][4]
# Out:
# 'Disney’s Wilderness Lodge '

# %%
fuzz.token_sort_ratio("Disney's Wilderness Lodge", df_resort_areas['Resort'][4])
# Out:
# 100

# %%
df['Resort'][3]
# Out:
# "Boulder Ridge Villas at Disney's Wilderness Lodge"

# %%
fuzz.token_sort_ratio("Disney's Wilderness Lodge", df_resort_areas['Resort'][0])
# Out:
# 62

# %% [markdown]
# #### Use FuzzyWuzzy to match resort hotel names in addresses dataframe and resort areas dataframe.

# %% [markdown]
# #### After experimenting with the ratio, 89 appeared to be the best value to match resort hotel names without causing issues that were more difficult to fix.

# %%
for i in range(len(df_resort_areas)):
    for j in range(len(df)):
        if fuzz.token_sort_ratio(df['Resort'][j], df_resort_areas['Resort'][i]) > 89:
            df['Resort'][j]=df_resort_areas['Resort'][i]

# %%
df
# Out:
#                                                Resort  \
# 0         B Resort & Spa - Disney Springs Resort Area
# 1     Bay Lake Tower at Disney’s Contemporary Resort
# 2   Best Western Lake Buena Vista - Disney Springs...
# 3   Boulder Ridge Villas at Disney's Wilderness Lodge
# 4   Copper Creek Villas & Cabins at Disney's Wilde...
# 5                    Disney’s All-Star Movies Resort
# 6                     Disney’s All-Star Music Resort
# 7                   Disney’s All-Star Sports Resort
# 8        Disney’s Animal Kingdom Lodge  - Jambo House
# 9    Disney’s Animal Kingdom Villas  - Kidani Village
# 10                  Disney’s Art of Animation Resort
# 11                        Disney’s Beach Club Resort
# 31   10100 Dream Tree Blvd Lake Buena Vista, FL 32836
# 32  1900 Buena Vista Drive Lake Buena Vista, FL 32830
# 33       1751 Hotel Plaza Boulevard Orlando, FL 32830
# 34  1805 Hotel Plaza Boulevard Lake Buena Vista, F...
# 35  1950 West Magnolia Palm Drive Lake Buena Vista...
# 36  1500 Epcot Resort Boulevard Lake Buena Vista, ...
# 37  4510 North Fort Wilderness Trail Orlando, FL 3...
# 38               4401 Floridian Way Orlando, FL 32830
# 39           1960 Broadway Lake Buena Vista, FL 32830
# 40  1850B Hotel Plaza Boulevard Lake Buena Vista, ...

# %%
df_resort_areas['Resort'][20]
# Out:
# 'Disney’s Animal Kingdom Lodge  - Jambo House'

# %% [markdown]
# #### Join resort areas dataframe and addresses dataframe on resort hotel names.  As previously stated, the resort areas dataframe is used as the master list, which is why a left join is used.

# %%
joined=df_resort_areas.join(df.set_index('Resort'), how='left', on='Resort')
joined
# Out:
#                                                Resort     Resort Area  \
# 0   Copper Creek Villas & Cabins at Disney's Wilde...   Magic Kingdom
# 1                       Disney’s Contemporary Resort    Magic Kingdom
# 2                    Disney’s Grand Floridian Resort    Magic Kingdom
# 3                  Disney's Polynesian Village Resort   Magic Kingdom
# 4                          Disney’s Wilderness Lodge    Magic Kingdom
# 5     Bay Lake Tower at Disney’s Contemporary Resort    Magic Kingdom
# 6   The Villas at Disney’s Grand Floridian Resort ...   Magic Kingdom
# 7   Boulder Ridge Villas at Disney's Wilderness Lodge   Magic Kingdom
# 8             Disney’s Fort Wilderness Resort Cabins    Magic Kingdom
# 9                         Disney’s Beach Club Resort            Epcot
# 10                            Disney’s BoardWalk Inn            Epcot
# 11                        Disney’s Yacht Club Resort            Epcot
# 12                      Dolphin at Walt Disney World            Epcot
# 13                         Swan at Walt Disney World            Epcot
# 14                        Disney’s Beach Club Villas            Epcot
# 15                         Disney’s BoardWalk Villas            Epcot
# 16                           Disney's Riviera Resort            Epcot
# 17                   Disney’s Caribbean Beach Resort            Epcot
# 18                  Disney’s Art of Animation Resort            Epcot
# 19                       Disney’s Pop Century Resort            Epcot
# 20       Disney’s Animal Kingdom Lodge  - Jambo House  Animal Kingdom
# 21   Disney’s Animal Kingdom Villas  - Kidani Village  Animal Kingdom
# 22                  Disney’s Coronado Springs Resort   Animal Kingdom
# 23                   Disney’s All-Star Movies Resort   Animal Kingdom
# 24                    Disney’s All-Star Music Resort   Animal Kingdom
# 25                  Disney’s All-Star Sports Resort    Animal Kingdom
# 26                      Disney’s Old Key West Resort   Disney Springs
# 27            Disney’s Saratoga Springs Resort & Spa   Disney Springs
# 28     Disney’s Port Orleans Resort – French Quarter   Disney Springs
# 29          Disney’s Port Orleans Resort – Riverside   Disney Springs
#
#                                               Address
# 0              901 Timberline Drive Orlando, FL 32830
# 1            4600 North World Drive Orlando, FL 32830
# 2                4401 Floridian Way Orlando, FL 32830
# 3             1600 Seven Seas Drive Orlando, FL 32830
# 4              901 Timberline Drive Orlando, FL 32830
# 5   4600 North World Drive Lake Buena Vista, FL 32830
# 6                4401 Floridian Way Orlando, FL 32830
# 7              901 Timberline Drive Orlando, FL 32830
# 8   4510 North Fort Wilderness Trail Orlando, FL 3...
# 9   1800 Epcot Resort Boulevard Lake Buena Vista, ...
# 10      2101 Epcot Resort Boulevard Orlando, FL 32830
# 11      1700 Epcot Resort Boulevard Orlando, FL 32830
# 12  1500 Epcot Resort Boulevard Lake Buena Vista, ...
# 13  1500 Epcot Resort Boulevard Lake Buena Vista, ...
# 14  1900 Epcot Resort Boulevard Lake Buena Vista, ...
# 15      2101 Epcot Resort Boulevard Orlando, FL 32830
# 16      1080 Esplanade Ave Lake Buena Vista, FL 32830
# 17                   900 Cayman Way Orlando, FL 32830
# 18      1850 Animation Way Lake Buena Vista, FL 32830
# 19      1050 Century Drive Lake Buena Vista, FL 32830
# 20            2901 Osceola Parkway Bay Lake, FL 32830
# 21    2901 Osceola Parkway Lake Buena Vista, FL 32830
# 22      1000 West Buena Vista Drive Orlando, FL 32830
# 23  1901 West Buena Vista Drive Lake Buena Vista, ...
# 24  1801 West Buena Vista Drive Lake Buena Vista, ...
# 25      1701 West Buena Vista Drive Orlando, FL 32830
# 26             1510 North Cove Road Orlando, FL 32830
# 27  1901 East Buena Vista Drive Lake Buena Vista, ...
# 28      2201 Orleans Drive Lake Buena Vista, FL 32830
# 29    1251 Riverside Drive Lake Buena Vista, FL 32830

# %%
joined['Address'].isnull().sum()
# Out:
# 0

# %%
joined[joined['Address'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [Resort, Resort Area, Address]
# Index: []

# %% [markdown]
# #### Use FuzzyWuzzy to match resort hotel names in number of rooms dataframe and new joined dataframe.

# %%
for i in range(len(joined)):
    for j in range(len(df_rooms)):
        if fuzz.token_sort_ratio(df_rooms['Resort'][j], joined['Resort'][i]) > 89:
            df_rooms['Resort'][j]=joined['Resort'][i]

# %%
df_rooms.head()
# Out:
#                                               Resort Number of Rooms
# 0        B Resort & Spa - Disney Springs Resort Area             394
# 1    Bay Lake Tower at Disney’s Contemporary Resort              295
# 2  Best Western Lake Buena Vista - Disney Springs...             325
# 3  Boulder Ridge Villas at Disney's Wilderness Lodge             136
# 4  Copper Creek Villas & Cabins at Disney's Wilde...             220

# %% [markdown]
# #### Join number of rooms dataframe with the new joined dataframe on resort hotel name.

# %%
joined=joined.join(df_rooms.set_index('Resort'), how='left', on='Resort')
joined
# Out:
#                                                Resort     Resort Area  \
# 0   Copper Creek Villas & Cabins at Disney's Wilde...   Magic Kingdom
# 1                       Disney’s Contemporary Resort    Magic Kingdom
# 2                    Disney’s Grand Floridian Resort    Magic Kingdom
# 3                  Disney's Polynesian Village Resort   Magic Kingdom
# 4                          Disney’s Wilderness Lodge    Magic Kingdom
# 5     Bay Lake Tower at Disney’s Contemporary Resort    Magic Kingdom
# 6   The Villas at Disney’s Grand Floridian Resort ...   Magic Kingdom
# 7   Boulder Ridge Villas at Disney's Wilderness Lodge   Magic Kingdom
# 8             Disney’s Fort Wilderness Resort Cabins    Magic Kingdom
# 9                         Disney’s Beach Club Resort            Epcot
# 10                            Disney’s BoardWalk Inn            Epcot
